# %%
# !pip install xarray scipy pycwt netcdf4 statsmodels
# Out:
# Requirement already satisfied: xarray in .\.venv\Lib\site-packages (2026.7.0)
# Requirement already satisfied: scipy in .\.venv\Lib\site-packages (1.18.0)
# Requirement already satisfied: pycwt in .\.venv\Lib\site-packages (0.5.0b0)
# Requirement already satisfied: netcdf4 in .\.venv\Lib\site-packages (1.7.4)
# Requirement already satisfied: statsmodels in .\.venv\Lib\site-packages (0.14.6)
# Requirement already satisfied: numpy>=1.26 in .\.venv\Lib\site-packages (from xarray) (2.5.1)
# Requirement already satisfied: packaging>=24.2 in .\.venv\Lib\site-packages (from xarray) (26.2)
# Requirement already satisfied: pandas>=2.2 in .\.venv\Lib\site-packages (from xarray) (3.0.3)
# Requirement already satisfied: matplotlib<4,>=3.7 in .\.venv\Lib\site-packages (from pycwt) (3.11.0)
# Requirement already satisfied: tqdm<5,>=4.65 in .\.venv\Lib\site-packages (from pycwt) (4.68.4)
# Requirement already satisfied: contourpy>=1.0.1 in .\.venv\Lib\site-packages (from matplotlib<4,>=3.7->pycwt) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in .\.venv\Lib\site-packages (from matplotlib<4,>=3.7->pycwt) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in .\.venv\Lib\site-packages (from matplotlib<4,>=3.7->pycwt) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in .\.venv\Lib\site-packages (from matplotlib<4,>=3.7->pycwt) (1.5.0)
# Requirement already satisfied: pillow>=9 in .\.venv\Lib\site-packages (from matplotlib<4,>=3.7->pycwt) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in .\.venv\Lib\site-packages (from matplotlib<4,>=3.7->pycwt) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in .\.venv\Lib\site-packages (from matplotlib<4,>=3.7->pycwt) (2.9.0.post0)
# Requirement already satisfied: colorama in .\.venv\Lib\site-packages (from tqdm<5,>=4.65->pycwt) (0.4.6)
# Requirement already satisfied: cftime in .\.venv\Lib\site-packages (from netcdf4) (1.6.5)
# Requirement already satisfied: certifi in .\.venv\Lib\site-packages (from netcdf4) (2026.6.17)
# Requirement already satisfied: patsy>=0.5.6 in .\.venv\Lib\site-packages (from statsmodels) (1.0.2)
# Requirement already satisfied: tzdata in .\.venv\Lib\site-packages (from pandas>=2.2->xarray) (2026.3)
# Requirement already satisfied: six>=1.5 in .\.venv\Lib\site-packages (from python-dateutil>=2.7->matplotlib<4,>=3.7->pycwt) (1.17.0)

# %%
# Plotagem de anomalias mensais (2010-2030)
months = ['Jan', 'Fev', 'Mar', 'Abr', 'Mai', 'Jun', 'Jul', 'Ago', 'Set', 'Out', 'Nov', 'Dez']
index = np.arange(len(months))
bar_width = 0.35

fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(18, 5))
data = [
    (anom_CCSM4_rcp45_montly.values, anom_CCSM4_rcp85_monthly.values, 'CCSM4'),
    (anom_ACCESS1_3_rcp45_montly.values, anom_ACCESS1_3_rcp85_monthly.values, 'ACCESS1_3'),
    (anom_HadGEM2_ES_rcp45_montly.values, anom_HadGEM2_ES_rcp85_monthly.values, 'HadGEM2_ES')
]

for ax, (anom_rcp45, anom_rcp85, title) in zip(axes, data):
    ax.bar(index - bar_width/2, anom_rcp45, bar_width, label='RCP4.5', color='skyblue')
    ax.bar(index + bar_width/2, anom_rcp85, bar_width, label='RCP8.5', color='salmon')
    ax.set_xlabel('Mês')
    ax.set_ylabel('Anomalia de Precipitação (mm/mês)')
    ax.set_title(f'Anomalia mensal: {title} (2010-2030)')
    ax.set_xticks(index)
    ax.set_xticklabels(months, rotation=45)
    ax.axhline(0, color='black', linewidth=0.8)
    y_abs_max = max(abs(anom_rcp45.min()), abs(anom_rcp45.max()), abs(anom_rcp85.min()), abs(anom_rcp85.max()))
    ax.set_ylim(-y_abs_max*1.1, y_abs_max*1.1)
    ax.legend()

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
#
# AttributeError                            Traceback (most recent call last)
#
# Cell In[22], line 8
#
#       4 bar_width = 0.35
#
#       5
#
#       6 fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(18, 5))
#
#       7 data = [
#
# ----> 8     (anom_CCSM4_rcp45_montly.to_numpy(), anom_CCSM4_rcp85_monthly.to_numpy(), 'CCSM4'),
#
#       9     (anom_ACCESS1_3_rcp45_montly.to_numpy(), anom_ACCESS1_3_rcp85_monthly.to_numpy(), 'ACCESS1_3'),
#
#      10     (anom_HadGEM2_ES_rcp45_montly.to_numpy(), anom_HadGEM2_ES_rcp85_monthly.to_numpy(), 'HadGEM2_ES')
#
#      11 ]
#
#
#
# File c:\Users\gabri\Downloads\UGRH\.venv\Lib\site-packages\xarray\core\common.py:306, in AttrAccessMixin.__getattr__(self, name)
#
#     304         with suppress(KeyError):
#
#     305             return source[name]
#
# --> 306 raise AttributeError(
#
#     307     f"{type(self).__name__!r} object has no attribute {name!r}"
#
#     308 )
#
#
#
# AttributeError: 'Dataset' object has no attribute 'to_numpy'

# %%
# Importação das bibliotecas principais
import xarray as xr
import numpy as np
from scipy import stats
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Carregamento dos dados NetCDF de Precipitação
precip_GPCC = xr.open_dataset('./Dados/precip_GPCC.nc').precip
precip_NCEP = xr.open_dataset('./Dados/precip_NCEP.nc').prate

# %%
# Cálculo das médias espaciais para a área de interesse
mean_GPCC = precip_GPCC.mean(dim=['latitude', 'longitude'])
mean_NCEP = precip_NCEP.mean(dim=['latitude', 'longitude'])

# %%
# Cálculo das anomalias mensais (com base na climatologia de 1981 a 2011)
anom_NCEP = mean_NCEP - mean_NCEP.sel(time=slice('1981', '2011')).mean(dim='time')
anom_GPCC = mean_GPCC - mean_GPCC.sel(time=slice('1981', '2011')).mean(dim='time')

# %%
# Conversão dos dados de anomalia para DataFrames do Pandas
df_NCEP = anom_NCEP.to_dataframe()
df_NCEP.index = df_NCEP.index.strftime('%Y-%m')
df_NCEP = df_NCEP.rename(columns={'prate' : 'precip'}).reset_index()

df_GPCC = anom_GPCC.to_dataframe()
df_GPCC.index = df_GPCC.index.strftime('%Y-%m')
df_GPCC = df_GPCC.reset_index()

# %%
# Exibição das informações estruturais dos DataFrames
df_NCEP.info()
print('-'*50)
df_GPCC.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 932 entries, 0 to 931
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   time    932 non-null    str
#  1   precip  932 non-null    float32
# dtypes: float32(1), str(1)
# memory usage: 11.1 KB
# --------------------------------------------------
# <class 'pandas.DataFrame'>
# RangeIndex: 1488 entries, 0 to 1487
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   time    1488 non-null   str
#  1   precip  1488 non-null   float32
# dtypes: float32(1), str(1)
# memory usage: 17.6 KB

# %%
# Plotagem inicial da anomalia de precipitação do NCEP
fig, ax = plt.subplots(figsize=(12, 5))
df_NCEP['precip'].plot(ax=ax)
plt.title('Série de Anomalia de Precipitação - NCEP')
plt.xlabel('Meses (Indexados)')
plt.ylabel('Precipitação Anômala (mm/mês)')
plt.show()

# %%
# Função auxiliar para realizar a análise wavelet completa e plotar os resultados
def plot_wavelet_analysis(df, val_col, title, label, units, date_col='time',
                           periodo_interesse=[0, 1], significance_level=0.75,
                           save_filename=None, figsize_overall=(11, 8)):
    import numpy as np
    import matplotlib.pyplot as plt
    import pycwt as wavelet
    from pycwt.helpers import find
    
    # 1. Preparar os dados
    dat = np.array(df[val_col])
    dt = 1/12  # em anos (dado mensal)
    t0 = 0
    N = dat.size
    
    # Tentar construir o eixo de anos baseado nas datas reais
    try:
        if date_col in df.columns:
            start_year = int(df[date_col].iloc[0].split('-')[0])
        else:
            start_year = df.index[0].year
        t = np.arange(start_year, start_year + N * dt, dt)[:N]
        end_year = t[-1] + dt
    except Exception:
        t = np.arange(0, N) * dt + t0
        start_year = t.min()
        end_year = t.max()
        
    # 2. Remover a tendência linear e normalizar
    p = np.polyfit(t - t.min(), dat, 1)
    dat_notrend = dat - np.polyval(p, t - t.min())
    std = dat_notrend.std()
    var = std ** 2
    dat_norm = dat_notrend / std
    
    # 3. Parâmetros da wavelet
    mother = wavelet.Morlet(6)
    s0 = 2 * dt
    dj = 1 / 12
    J = 8 / dj
    alpha, _, _ = wavelet.ar1(dat)  # Autocorrelação Lag-1 para ruído vermelho
    
    # 4. Transformada Wavelet
    wave, scales, freqs, coi, fft, fftfreqs = wavelet.cwt(dat_norm, dt, dj, s0, J, mother)
    iwave = wavelet.icwt(wave, scales, dt, dj, mother) * std
    
    power = (np.abs(wave)) ** 2
    fft_power = np.abs(fft) ** 2
    period = 1 / freqs
    
    # 5. Significância e espectros teóricos
    signif, fft_theor = wavelet.significance(1.0, dt, scales, 0, alpha,
                                             significance_level=significance_level,
                                             wavelet=mother)
    sig95 = np.ones([1, N]) * signif[:, None]
    sig95 = power / sig95
    
    # Espectro Wavelet Global
    glbl_power = power.mean(axis=1)
    dof = N - scales
    glbl_signif, tmp = wavelet.significance(var, dt, scales, 1, alpha,
                                            significance_level=significance_level,
                                            dof=dof, wavelet=mother)
                                            
    # Média da escala
    sel = find((period >= periodo_interesse[0]) & (period <= periodo_interesse[1]))
    Cdelta = mother.cdelta
    scale_avg = (scales * np.ones((N, 1))).transpose()
    scale_avg = power / scale_avg
    scale_avg = var * dj * dt / Cdelta * scale_avg[sel, :].sum(axis=0)
    scale_avg_signif, tmp = wavelet.significance(var, dt, scales, 2, alpha,
                                                 significance_level=significance_level,
                                                 dof=[scales[sel[0]], scales[sel[-1]]],
                                                 wavelet=mother)
                                                 
    # 6. Plotagem
    fig = plt.figure(figsize=figsize_overall)
    
    # Sub-gráfico a) Série temporal original e wavelet inversa
    ax = plt.axes([0.1, 0.75, 0.65, 0.2])
    ax.plot(t, iwave, '-', linewidth=1, color=[0.5, 0.5, 0.5], label='Wavelet Inversa')
    ax.plot(t, dat, 'k', linewidth=1.5, label='Original')
    ax.set_title(f'a) {title}', fontsize=10)
    ax.set_ylabel(f'{label} [{units}]', fontsize=9)
    ax.set_xlim([start_year, end_year])
    
    # Sub-gráfico b) Espectro de potência wavelet
    bx = plt.axes([0.1, 0.39, 0.65, 0.28], sharex=ax)
    levels = [0.0625, 0.125, 0.25, 0.5, 1, 2, 4, 8, 16, 32]
    bx.contourf(t, np.log2(period), np.log2(power), levels=np.log2(levels), extend='both', cmap=plt.cm.rainbow)
    extent = [t.min(), t.max(), np.log2(period.min()), np.log2(period.max())]
    bx.contour(t, np.log2(period), sig95, levels=[-99, 1], colors='k', linewidths=2, extent=extent)
    bx.fill(np.concatenate([t, t[-1:] + dt, t[-1:] + dt, t[:1] - dt, t[:1] - dt]),
            np.concatenate([np.log2(coi), [1e-9], np.log2(period[-1:]), np.log2(period[-1:]), [1e-9]]),
            'k', alpha=0.3, hatch='x')
    bx.set_title(f'b) Espectro de Potência Wavelet de {label} ({mother.name})', fontsize=10)
    bx.set_ylabel('Período (Anos)', fontsize=9)
    bx.set_xlim([start_year, end_year])
    
    Yticks = 2 ** np.arange(np.ceil(np.log2(period.min())), np.ceil(np.log2(period.max())))
    bx.set_yticks(np.log2(Yticks))
    bx.set_yticklabels(Yticks)
    
    # Sub-gráfico c) Espectro wavelet global e Fourier
    cx = plt.axes([0.77, 0.39, 0.2, 0.28], sharey=bx)
    cx.plot(glbl_signif, np.log2(period), 'k--')
    cx.plot(var * fft_theor, np.log2(period), '--', color='#cccccc')
    cx.plot(var * fft_power, np.log2(1./fftfreqs), '-', color='#cccccc', linewidth=1.)
    cx.plot(var * glbl_power, np.log2(period), 'k-', linewidth=1.5)
    cx.set_title('c) Espectro Global', fontsize=10)
    cx.set_xlabel(f'Poder [({units})^2]', fontsize=9)
    cx.set_ylim(np.log2([period.min(), period.max()]))
    cx.set_yticks(np.log2(Yticks))
    cx.set_yticklabels(Yticks)
    plt.setp(cx.get_yticklabels(), visible=False)
    
    # Sub-gráfico d) Espectro de ondas médias da escala (variância média)
    dx = plt.axes([0.1, 0.12, 0.65, 0.2], sharex=ax)
    dx.axhline(scale_avg_signif, color='k', linestyle='--', linewidth=1.)
    dx.plot(t, scale_avg, 'k-', linewidth=1.5)
    dx.set_title(f'd) {periodo_interesse[0]}--{periodo_interesse[1]} Anos (variância média da escala)', fontsize=10)
    dx.set_xlabel('Tempo (Ano)', fontsize=9)
    dx.set_ylabel(f'Variância Média [{units}]', fontsize=9)
    dx.set_xlim([start_year, end_year])
    
    if save_filename:
        plt.savefig(save_filename, dpi=600, bbox_inches='tight')
    plt.show()

# %% [markdown]
# # Análise de Wavelets - Dados NCEP
# Realizaremos a análise de wavelets tanto para a série de anomalia de precipitação bruta quanto para a série com remoção do ciclo sazonal.

# %%
# Análise Wavelet: Anomalia Bruta (NCEP)
plot_wavelet_analysis(
    df=df_NCEP,
    val_col='precip',
    title='Precipitação NCEP (Bruta)',
    label='Anomalia de Precipitação',
    units='mm/mês',
    save_filename='Wavelets_NCEP_Bruta.png'
)
# Out:
# c:\Users\gabri\Downloads\UGRH\.venv\Lib\site-packages\matplotlib\cbook.py:1810: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# c:\Users\gabri\Downloads\UGRH\.venv\Lib\site-packages\matplotlib\cbook.py:1407: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asanyarray(x, float)

# %%
# Decomposição Sazonal (NCEP)
from statsmodels.tsa.seasonal import seasonal_decompose
decomp_NCEP = seasonal_decompose(df_NCEP['precip'], model='additive', period=12, two_sided=True)
df_NCEP['no_season'] = df_NCEP['precip'] - decomp_NCEP.seasonal

# %%
# Análise Wavelet: Sem Ciclo Sazonal (NCEP)
plot_wavelet_analysis(
    df=df_NCEP,
    val_col='no_season',
    title='Precipitação NCEP (Sem Sazonalidade)',
    label='Anomalia Desestacionalizada',
    units='mm/mês',
    save_filename='Wavelets_NCEP_SemSazonalidade.png'
)
# Out:
# c:\Users\gabri\Downloads\UGRH\.venv\Lib\site-packages\matplotlib\cbook.py:1810: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# c:\Users\gabri\Downloads\UGRH\.venv\Lib\site-packages\matplotlib\cbook.py:1407: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asanyarray(x, float)

# %% [markdown]
# # Análise de Wavelets - Dados GPCC
# Da mesma forma, realizaremos a análise de wavelets para a série do GPCC.

# %%
# Análise Wavelet: Anomalia Bruta (GPCC)
plot_wavelet_analysis(
    df=df_GPCC,
    val_col='precip',
    title='Precipitação GPCC (Bruta)',
    label='Anomalia de Precipitação',
    units='mm/mês',
    save_filename='Wavelets_GPCC_Bruta.png'
)
# Out:
# c:\Users\gabri\Downloads\UGRH\.venv\Lib\site-packages\matplotlib\cbook.py:1810: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# c:\Users\gabri\Downloads\UGRH\.venv\Lib\site-packages\matplotlib\cbook.py:1407: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asanyarray(x, float)

# %%
# Decomposição Sazonal (GPCC)
from statsmodels.tsa.seasonal import seasonal_decompose
decomp_GPCC = seasonal_decompose(df_GPCC['precip'], model='additive', period=12, two_sided=True)
df_GPCC['no_season'] = df_GPCC['precip'] - decomp_GPCC.seasonal

# %%
# Análise Wavelet: Sem Ciclo Sazonal (GPCC)
plot_wavelet_analysis(
    df=df_GPCC,
    val_col='no_season',
    title='Precipitação GPCC (Sem Sazonalidade)',
    label='Anomalia Desestacionalizada',
    units='mm/mês',
    save_filename='Wavelets_GPCC_SemSazonalidade.png'
)
# Out:
# c:\Users\gabri\Downloads\UGRH\.venv\Lib\site-packages\matplotlib\cbook.py:1810: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# c:\Users\gabri\Downloads\UGRH\.venv\Lib\site-packages\matplotlib\cbook.py:1407: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asanyarray(x, float)
