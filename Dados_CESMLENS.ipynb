# %% [markdown]
# <a href="https://colab.research.google.com/github/Schimidel/UGRH-s-PrecipitacaoeTemperatura/blob/main/Dados_CESMLENS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# instalando tudo que precisamos (essa operação demora um pouco)
# %%capture
# !pip install s3fs          # módulo para montar buckets do AWS
# !pip install Intake-esm    # usamos isso para "vasculhar" o que tem na nuvem

# !pip install -U xarray[complete] # reinstala todo o xarray (útil nessa versão do colab por conta do cftime)

# !pip install salem  # e também com o salem e o rasterio
# !pip install rasterio

# !pip install cartopy # porque queremos fazer mapas legais.
# !pip install pandas>=2.1.0 # uma pequena atualização
# provavelmente o seu runtime irá reiniciar. Não tem problema ! É normal isso acontecer.
# o sistema irá reiniciar (note que a célula vai peder a barrinha verde)

# %%
import geopandas as gpd
import requests
import intake
import xarray
import matplotlib.pyplot as plt
import salem
# from google.colab import drive
# drive.mount(...)
# Out:
# Mounted at /content/drive

# %%
# URL do arquivo ZIP
url = "https://github.com/andrebelem/pythonverse/raw/main/datasets/SNIRH_UGRHs_2020.zip"

# Nome do arquivo local para salvar
nome_arquivo = "SNIRH_UGRHs_2020.zip"

# Faz o download do arquivo
response = requests.get(url)

# Verifica se a requisição foi bem-sucedida (código 200)
if response.status_code == 200:
    # Abre o arquivo local em modo de escrita em bytes
    with open(nome_arquivo, "wb") as f:
        # Escreve os dados no arquivo
        f.write(response.content)
    print("Download concluído com sucesso!")
# Out:
# Download concluído com sucesso!

# %%
gdf = gpd.read_file("SNIRH_UGRHs_2020.zip")

# Filtrar a bacia desejada (exemplo usando o Paraná)
parana = gdf[gdf.NOME == "Paraná"]

# %%
# agora vamos listar tudo que existe no cesm-lens (no S3 AWS Bucket). Notem que tudo isso está na nuvem
import intake
col = intake.open_esm_datastore("https://raw.githubusercontent.com/NCAR/cesm2-le-aws/main/intake-catalogs/aws-cesm2-le.json") # este é outro conjunto de dados

# %%
# o contudo do bucket está em um dataframe, e é visualizado abaixo.
col.df
# Out:
#     variable                                long_name component  experiment  \
# 0       FLNS             net longwave flux at surface       atm  historical
# 1      FLNSC    clearsky net longwave flux at surface       atm  historical
# 2       FLUT  upwelling longwave flux at top of model       atm  historical
# 3       FSNS                net solar flux at surface       atm  historical
# 4      FSNSC       clearsky net solar flux at surface       atm  historical
# ..       ...                                      ...       ...         ...
# 317     WVEL                        vertical velocity       ocn      ssp370
# 318      NaN                                      NaN       ocn  historical
# 319      NaN                                      NaN       ocn  historical
# 320      NaN                                      NaN       ocn      ssp370
# 321      NaN                                      NaN       ocn      ssp370
#
#     forcing_variant frequency  vertical_levels spatial_domain         units  \
# 0             cmip6     daily              1.0         global          W/m2
# 1             cmip6     daily              1.0         global          W/m2
# 2             cmip6     daily              1.0         global          W/m2
# 3             cmip6     daily              1.0         global          W/m2
# 4             cmip6     daily              1.0         global          W/m2
# ..              ...       ...              ...            ...           ...
# 317            smbb   monthly             60.0   global_ocean  centimeter/s
# 318            smbb    static              NaN   global_ocean           NaN
# 319           cmip6    static              NaN   global_ocean           NaN
# 320            smbb    static              NaN   global_ocean           NaN
# 321           cmip6    static              NaN   global_ocean           NaN
#
#               start_time             end_time  \
# 0    1850-01-01 12:00:00  2014-12-31 12:00:00
# 1    1850-01-01 12:00:00  2014-12-31 12:00:00
# 2    1850-01-01 12:00:00  2014-12-31 12:00:00
# 3    1850-01-01 12:00:00  2014-12-31 12:00:00
# 4    1850-01-01 12:00:00  2014-12-31 12:00:00
# ..                   ...                  ...
# 317  2015-01-16 12:00:00  2100-12-16 12:00:00
# 318                  NaN                  NaN
# 319                  NaN                  NaN
# 320                  NaN                  NaN
# 321                  NaN                  NaN
#
#                                                   path
# 0    s3://ncar-cesm2-lens/atm/daily/cesm2LE-histori...
# 1    s3://ncar-cesm2-lens/atm/daily/cesm2LE-histori...
# 2    s3://ncar-cesm2-lens/atm/daily/cesm2LE-histori...
# 3    s3://ncar-cesm2-lens/atm/daily/cesm2LE-histori...
# 4    s3://ncar-cesm2-lens/atm/daily/cesm2LE-histori...
# ..                                                 ...
# 317  s3://ncar-cesm2-lens/ocn/monthly/cesm2LE-ssp37...
# 318          s3://ncar-cesm2-lens/ocn/static/grid.zarr
# 319          s3://ncar-cesm2-lens/ocn/static/grid.zarr
# 320          s3://ncar-cesm2-lens/ocn/static/grid.zarr
# 321          s3://ncar-cesm2-lens/ocn/static/grid.zarr
#
# [322 rows x 12 columns]

# %%
# estou interessado (por exemplo, na variável que contém a "taxa de precipitação")
col_df = col.df
col_df = col_df.fillna('desconhecido')
col_df[col_df.long_name.str.contains('temperature')]
# Out:
#      variable                                          long_name component  \
# 14          T                                        temperature       atm
# 16     TREFHT                       reference height temperature       atm
# 17   TREFHTMN  minimum reference height temperature over outp...       atm
# 18   TREFHTMX  maximum reference height temperature over outp...       atm
# 19         TS                    surface temperature (radiative)       atm
# ..        ...                                                ...       ...
# 264      SNOW  atmospheric snow, after rain/snow repartitioni...       lnd
# 267  TREFMXAV           daily maximum of average 2-m temperature       lnd
# 271      TEMP                              potential temperature       ocn
# 293      TEMP                              potential temperature       ocn
# 308      TEMP                              potential temperature       ocn
#
#      experiment forcing_variant frequency vertical_levels spatial_domain  \
# 14   historical           cmip6     daily            32.0         global
# 16   historical           cmip6     daily             1.0         global
# 17   historical           cmip6     daily             1.0         global
# 18   historical           cmip6     daily             1.0         global
# 19   historical           cmip6     daily             1.0         global
# ..          ...             ...       ...             ...            ...
# 264      ssp370            smbb   monthly             1.0    global_land
# 267      ssp370            smbb   monthly             1.0    global_land
# 271  historical           cmip6   monthly            60.0   global_ocean
# 293      ssp370           cmip6   monthly            60.0   global_ocean
# 308      ssp370            smbb   monthly            60.0   global_ocean
#
#     units           start_time             end_time  \
# 14      K  1850-01-01 12:00:00  2014-12-31 12:00:00
# 16      K  1850-01-01 12:00:00  2014-12-31 12:00:00
# 17      K  1850-01-01 12:00:00  2014-12-31 12:00:00
# 18      K  1850-01-01 12:00:00  2014-12-31 12:00:00
# 19      K  1850-01-01 12:00:00  2014-12-31 12:00:00
# ..    ...                  ...                  ...
# 264  mm/s  2015-01-16 12:00:00  2100-12-16 12:00:00
# 267     K  2015-01-16 12:00:00  2100-12-16 12:00:00
# 271  degC  1850-01-16 12:00:00  2014-12-16 12:00:00
# 293  degC  2015-01-16 12:00:00  2100-12-16 12:00:00
# 308  degC  2015-01-16 12:00:00  2100-12-16 12:00:00
#
#                                                   path
# 14   s3://ncar-cesm2-lens/atm/daily/cesm2LE-histori...
# 16   s3://ncar-cesm2-lens/atm/daily/cesm2LE-histori...
# 17   s3://ncar-cesm2-lens/atm/daily/cesm2LE-histori...
# 18   s3://ncar-cesm2-lens/atm/daily/cesm2LE-histori...
# 19   s3://ncar-cesm2-lens/atm/daily/cesm2LE-histori...
# ..                                                 ...
# 264  s3://ncar-cesm2-lens/lnd/monthly/cesm2LE-ssp37...
# 267  s3://ncar-cesm2-lens/lnd/monthly/cesm2LE-ssp37...
# 271  s3://ncar-cesm2-lens/ocn/monthly/cesm2LE-histo...
# 293  s3://ncar-cesm2-lens/ocn/monthly/cesm2LE-ssp37...
# 308  s3://ncar-cesm2-lens/ocn/monthly/cesm2LE-ssp37...
#
# [63 rows x 12 columns]

# %%
col_df.loc[col_df.variable.str.contains("PREC")]
# Out:
#     variable                                          long_name component  \
# 6      PRECC          convective precipitation rate (liq + ice)       atm
# 7      PRECL  large-scale (stable) precipitation rate (liq +...       atm
# 8     PRECSC            convective snow rate (water equivalent)       atm
# 9     PRECSL  large-scale (stable) snow rate (water equivalent)       atm
# 29     PRECC          convective precipitation rate (liq + ice)       atm
# 30     PRECL  large-scale (stable) precipitation rate (liq +...       atm
# 31    PRECSC            convective snow rate (water equivalent)       atm
# 32    PRECSL  large-scale (stable) snow rate (water equivalent)       atm
# 52     PRECC          convective precipitation rate (liq + ice)       atm
# 53     PRECL  large-scale (stable) precipitation rate (liq +...       atm
# 54    PRECSC            convective snow rate (water equivalent)       atm
# 55    PRECSL  large-scale (stable) snow rate (water equivalent)       atm
# 74     PRECC          convective precipitation rate (liq + ice)       atm
# 75     PRECL  large-scale (stable) precipitation rate (liq +...       atm
# 76    PRECSC            convective snow rate (water equivalent)       atm
# 77    PRECSL  large-scale (stable) snow rate (water equivalent)       atm
# 94     PRECC          convective precipitation rate (liq + ice)       atm
# 95     PRECL  large-scale (stable) precipitation rate (liq +...       atm
# 96    PRECSC            convective snow rate (water equivalent)       atm
# 97    PRECSL  large-scale (stable) snow rate (water equivalent)       atm
# 118    PRECC          convective precipitation rate (liq + ice)       atm
# 119    PRECL  large-scale (stable) precipitation rate (liq +...       atm
# 120   PRECSC            convective snow rate (water equivalent)       atm
# 121   PRECSL  large-scale (stable) snow rate (water equivalent)       atm
# 142    PRECC          convective precipitation rate (liq + ice)       atm
# 143    PRECL  large-scale (stable) precipitation rate (liq +...       atm
# 144   PRECSC            convective snow rate (water equivalent)       atm
# 145   PRECSL  large-scale (stable) snow rate (water equivalent)       atm
# 166    PRECC          convective precipitation rate (liq + ice)       atm
# 167    PRECL  large-scale (stable) precipitation rate (liq +...       atm
# 168   PRECSC            convective snow rate (water equivalent)       atm
# 169   PRECSL  large-scale (stable) snow rate (water equivalent)       atm
#
#      experiment forcing_variant frequency vertical_levels spatial_domain  \
# 6    historical           cmip6     daily             1.0         global
# 7    historical           cmip6     daily             1.0         global
# 8    historical           cmip6     daily             1.0         global
# 9    historical           cmip6     daily             1.0         global
# 29   historical            smbb     daily             1.0         global
# 30   historical            smbb     daily             1.0         global
# 31   historical            smbb     daily             1.0         global
# 32   historical            smbb     daily             1.0         global
# 52       ssp370           cmip6     daily             1.0         global
# 53       ssp370           cmip6     daily             1.0         global
# 54       ssp370           cmip6     daily             1.0         global
# 55       ssp370           cmip6     daily             1.0         global
# 74       ssp370            smbb     daily             1.0         global
# 75       ssp370            smbb     daily             1.0         global
# 76       ssp370            smbb     daily             1.0         global
# 77       ssp370            smbb     daily             1.0         global
# 94   historical           cmip6   monthly             1.0         global
# 95   historical           cmip6   monthly             1.0         global
# 96   historical           cmip6   monthly             1.0         global
# 97   historical           cmip6   monthly             1.0         global
# 118  historical            smbb   monthly             1.0         global
# 119  historical            smbb   monthly             1.0         global
# 120  historical            smbb   monthly             1.0         global
# 121  historical            smbb   monthly             1.0         global
# 142      ssp370           cmip6   monthly             1.0         global
# 143      ssp370           cmip6   monthly             1.0         global
# 144      ssp370           cmip6   monthly             1.0         global
# 145      ssp370           cmip6   monthly             1.0         global
# 166      ssp370            smbb   monthly             1.0         global
# 167      ssp370            smbb   monthly             1.0         global
# 168      ssp370            smbb   monthly             1.0         global
# 169      ssp370            smbb   monthly             1.0         global
#
#     units           start_time             end_time  \
# 6     m/s  1850-01-01 12:00:00  2014-12-31 12:00:00
# 7     m/s  1850-01-01 12:00:00  2014-12-31 12:00:00
# 8     m/s  1850-01-01 12:00:00  2014-12-31 12:00:00
# 9     m/s  1850-01-01 12:00:00  2014-12-31 12:00:00
# 29    m/s  1850-01-01 12:00:00  2014-12-31 12:00:00
# 30    m/s  1850-01-01 12:00:00  2014-12-31 12:00:00
# 31    m/s  1850-01-01 12:00:00  2014-12-31 12:00:00
# 32    m/s  1850-01-01 12:00:00  2014-12-31 12:00:00
# 52    m/s  2015-01-01 12:00:00  2100-12-31 12:00:00
# 53    m/s  2015-01-01 12:00:00  2100-12-31 12:00:00
# 54    m/s  2015-01-01 12:00:00  2100-12-31 12:00:00
# 55    m/s  2015-01-01 12:00:00  2100-12-31 12:00:00
# 74    m/s  2015-01-01 12:00:00  2100-12-31 12:00:00
# 75    m/s  2015-01-01 12:00:00  2100-12-31 12:00:00
# 76    m/s  2015-01-01 12:00:00  2100-12-31 12:00:00
# 77    m/s  2015-01-01 12:00:00  2100-12-31 12:00:00
# 94    m/s  1850-01-16 12:00:00  2014-12-16 12:00:00
# 95    m/s  1850-01-16 12:00:00  2014-12-16 12:00:00
# 96    m/s  1850-01-16 12:00:00  2014-12-16 12:00:00
# 97    m/s  1850-01-16 12:00:00  2014-12-16 12:00:00
# 118   m/s  1850-01-16 12:00:00  2014-12-16 12:00:00
# 119   m/s  1850-01-16 12:00:00  2014-12-16 12:00:00
# 120   m/s  1850-01-16 12:00:00  2014-12-16 12:00:00
# 121   m/s  1850-01-16 12:00:00  2014-12-16 12:00:00
# 142   m/s  2015-01-16 12:00:00  2100-12-16 12:00:00
# 143   m/s  2015-01-16 12:00:00  2100-12-16 12:00:00
# 144   m/s  2015-01-16 12:00:00  2100-12-16 12:00:00
# 145   m/s  2015-01-16 12:00:00  2100-12-16 12:00:00
# 166   m/s  2015-01-16 12:00:00  2100-12-16 12:00:00
# 167   m/s  2015-01-16 12:00:00  2100-12-16 12:00:00
# 168   m/s  2015-01-16 12:00:00  2100-12-16 12:00:00
# 169   m/s  2015-01-16 12:00:00  2100-12-16 12:00:00
#
#                                                   path
# 6    s3://ncar-cesm2-lens/atm/daily/cesm2LE-histori...
# 7    s3://ncar-cesm2-lens/atm/daily/cesm2LE-histori...
# 8    s3://ncar-cesm2-lens/atm/daily/cesm2LE-histori...
# 9    s3://ncar-cesm2-lens/atm/daily/cesm2LE-histori...
# 29   s3://ncar-cesm2-lens/atm/daily/cesm2LE-histori...
# 30   s3://ncar-cesm2-lens/atm/daily/cesm2LE-histori...
# 31   s3://ncar-cesm2-lens/atm/daily/cesm2LE-histori...
# 32   s3://ncar-cesm2-lens/atm/daily/cesm2LE-histori...
# 52   s3://ncar-cesm2-lens/atm/daily/cesm2LE-ssp370-...
# 53   s3://ncar-cesm2-lens/atm/daily/cesm2LE-ssp370-...
# 54   s3://ncar-cesm2-lens/atm/daily/cesm2LE-ssp370-...
# 55   s3://ncar-cesm2-lens/atm/daily/cesm2LE-ssp370-...
# 74   s3://ncar-cesm2-lens/atm/daily/cesm2LE-ssp370-...
# 75   s3://ncar-cesm2-lens/atm/daily/cesm2LE-ssp370-...
# 76   s3://ncar-cesm2-lens/atm/daily/cesm2LE-ssp370-...
# 77   s3://ncar-cesm2-lens/atm/daily/cesm2LE-ssp370-...
# 94   s3://ncar-cesm2-lens/atm/monthly/cesm2LE-histo...
# 95   s3://ncar-cesm2-lens/atm/monthly/cesm2LE-histo...
# 96   s3://ncar-cesm2-lens/atm/monthly/cesm2LE-histo...
# 97   s3://ncar-cesm2-lens/atm/monthly/cesm2LE-histo...
# 118  s3://ncar-cesm2-lens/atm/monthly/cesm2LE-histo...
# 119  s3://ncar-cesm2-lens/atm/monthly/cesm2LE-histo...
# 120  s3://ncar-cesm2-lens/atm/monthly/cesm2LE-histo...
# 121  s3://ncar-cesm2-lens/atm/monthly/cesm2LE-histo...
# 142  s3://ncar-cesm2-lens/atm/monthly/cesm2LE-ssp37...
# 143  s3://ncar-cesm2-lens/atm/monthly/cesm2LE-ssp37...
# 144  s3://ncar-cesm2-lens/atm/monthly/cesm2LE-ssp37...
# 145  s3://ncar-cesm2-lens/atm/monthly/cesm2LE-ssp37...
# 166  s3://ncar-cesm2-lens/atm/monthly/cesm2LE-ssp37...
# 167  s3://ncar-cesm2-lens/atm/monthly/cesm2LE-ssp37...
# 168  s3://ncar-cesm2-lens/atm/monthly/cesm2LE-ssp37...
# 169  s3://ncar-cesm2-lens/atm/monthly/cesm2LE-ssp37...

# %%
# vou fazer um subset onde separo apenas o que eu quero, frequẽncia diária
col_subset = col.search(experiment=["historical","ssp370"], frequency="monthly", variable=["PRECC", "PRECL", "T"], forcing_variant='cmip6')

# %%
# agora vou criar datasets do meu subset
dsets = col_subset.to_dataset_dict(zarr_kwargs={"consolidated": True}, storage_options={"anon": True})
# Out:
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'component.experiment.frequency.forcing_variant'
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='2' class='' max='2' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [2/2 00:02&lt;00:00]
#     </div>

# %%
dsets.keys() # podemos verificar se ele contém o que precisamos aqui.
# Out:
# dict_keys(['atm.historical.monthly.cmip6', 'atm.ssp370.monthly.cmip6'])

# %%
ds1 = dsets['atm.historical.monthly.cmip6']
ds2 = dsets['atm.ssp370.monthly.cmip6']

# %%
ds1
# Out:
# <xarray.Dataset> Size: 745GB
# Dimensions:    (member_id: 50, time: 1980, lat: 192, lon: 288, nbnd: 2, lev: 32)
# Coordinates:
#   * lat        (lat) float64 2kB -90.0 -89.06 -88.12 -87.17 ... 88.12 89.06 90.0
#   * lon        (lon) float64 2kB 0.0 1.25 2.5 3.75 ... 355.0 356.2 357.5 358.8
#   * member_id  (member_id) <U12 2kB 'r10i1181p1f1' ... 'r9i1301p1f1'
#   * time       (time) object 16kB 1850-01-16 12:00:00 ... 2014-12-16 12:00:00
#     time_bnds  (time, nbnd) object 32kB dask.array<chunksize=(1980, 2), meta=np.ndarray>
#   * lev        (lev) float64 256B 3.643 7.595 14.36 24.61 ... 957.5 976.3 992.6
# Dimensions without coordinates: nbnd
# Data variables:
#     PRECC      (member_id, time, lat, lon) float32 22GB dask.array<chunksize=(1, 600, 192, 288), meta=np.ndarray>
#     PRECL      (member_id, time, lat, lon) float32 22GB dask.array<chunksize=(1, 600, 192, 288), meta=np.ndarray>
#     T          (member_id, time, lev, lat, lon) float32 701GB dask.array<chunksize=(1, 24, 32, 192, 288), meta=np.ndarray>
# Attributes: (12/16)
#     Conventions:                       CF-1.0
#     NCO:                               netCDF Operators version 4.9.4 (Homepa...
#     logname:                           sunseon
#     model_doi_url:                     https://doi.org/10.5065/D67H1H0V
#     source:                            CAM
#     time_period_freq:                  month_1
#     ...                                ...
#     intake_esm_attrs:frequency:        monthly
#     intake_esm_attrs:spatial_domain:   global
#     intake_esm_attrs:start_time:       1850-01-16 12:00:00
#     intake_esm_attrs:end_time:         2014-12-16 12:00:00
#     intake_esm_attrs:_data_format_:    zarr
#     intake_esm_dataset_key:            atm.historical.monthly.cmip6

# %%
import xarray as xr
ds_CESM = xr.concat([ds1, ds2], dim="time")
ds_CESM = ds_CESM.sel(lev=1000, method='nearest')
#ds_CESM = ds_CESM.mean(dim='member_id')

# %%
#Converte o grid de 0x360 lon para -180x180
ds_CESM.coords['lon'] = (ds_CESM.coords['lon'] + 180) % 360 - 180
ds_CESM = ds_CESM.sortby(ds_CESM.lon)

# %%
#ds_CESM = ds_CESM.isel(member_id=0)

# %%
import geopandas as gpd
from shapely.geometry import Polygon

# Obter os limites do polígono (vértices extremos)
bounds = parana.geometry.bounds

# Extrair coordenadas dos limites
min_x, min_y, max_x, max_y = bounds.minx.min(), bounds.miny.min(), bounds.maxx.max(), bounds.maxy.max()

# Criar um quadrado com base nos limites
quadrado = Polygon([(min_x, min_y), (max_x, min_y), (max_x, max_y), (min_x, max_y)])

# Criar um GeoDataFrame para o quadrado
quadrado_gdf = gpd.GeoDataFrame(geometry=[quadrado], crs=parana.crs)

# %%
CESM_sel_prec = ds_CESM[['PRECC', 'PRECL']].salem.subset(shape=quadrado_gdf)
CESM_sel_T = ds_CESM['T'].salem.subset(shape=quadrado_gdf)

# %%
# vou fazer um plot "decente" de um dia qualquer com o semiárido
# note que copiei o código lá de cima

import matplotlib.pyplot as plt
import numpy as np
import cartopy.crs as ccrs
from cartopy.feature import NaturalEarthFeature, LAND, COASTLINE

plt.figure(figsize=(14,6))
ax = plt.axes(projection=ccrs.PlateCarree())
(CESM_sel_prec['PRECL'] * 1000* 24 * 30 * 60 * 60).isel(time=0, member_id=0).plot(ax=ax,
            transform=ccrs.PlateCarree(), x='lon', y='lat',
            cmap='PuRd', # altere os valores de vmax para ver o que acontece
            add_colorbar=True)

states = NaturalEarthFeature(category='cultural', scale='50m', facecolor='none',
                             name='admin_1_states_provinces_lines')
contries = NaturalEarthFeature(category='cultural', scale='50m', facecolor='none',
                             name='admin_0_countries')

ax.add_feature(states, facecolor='none', edgecolor='black')
ax.add_feature(contries, facecolor='none', edgecolor='black')

parana.geometry.plot(ax=ax,facecolor='none',edgecolor='blue',linewidth=2)

ax.coastlines()
# Out:
# /usr/local/lib/python3.11/dist-packages/cartopy/io/__init__.py:241: DownloadWarning: Downloading: https://naturalearth.s3.amazonaws.com/50m_cultural/ne_50m_admin_1_states_provinces_lines.zip
#   warnings.warn(f'Downloading: {url}', DownloadWarning)
# /usr/local/lib/python3.11/dist-packages/cartopy/io/__init__.py:241: DownloadWarning: Downloading: https://naturalearth.s3.amazonaws.com/50m_cultural/ne_50m_admin_0_countries.zip
#   warnings.warn(f'Downloading: {url}', DownloadWarning)
# /usr/local/lib/python3.11/dist-packages/cartopy/io/__init__.py:241: DownloadWarning: Downloading: https://naturalearth.s3.amazonaws.com/10m_physical/ne_10m_coastline.zip
#   warnings.warn(f'Downloading: {url}', DownloadWarning)

# %%
# Supondo que 'shapefile' seja o seu shapefile
parana_exp = parana.buffer(0.5)

# Supondo que 'parana_exp' seja seu GeoSeries
parana_exp = gpd.GeoDataFrame(geometry=parana_exp)
parana_exp.crs = parana.crs  # Atribua o mesmo CRS do GeoDataFrame original 'parana'

parana.plot()
parana_exp.plot()
# Out:
# <ipython-input-27-2905779000>:2: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   parana_exp = parana.buffer(0.5)
# <Axes: >

# %%
precip_CESM = CESM_sel_prec.salem.roi(shape=parana_exp)
temp_CESM =  CESM_sel_T.salem.roi(shape=parana_exp) # essa operação pode demorar um pouco dependendo do tamanho dos seus dados

# %%
# vou fazer um plot "decente" de um dia qualquer com o semiárido
# note que copiei o código lá de cima

import matplotlib.pyplot as plt
import numpy as np
import cartopy.crs as ccrs
from cartopy.feature import NaturalEarthFeature, LAND, COASTLINE

plt.figure(figsize=(14,6))
ax = plt.axes(projection=ccrs.PlateCarree())
precip_CESM['PRECL'].isel(time=0, member_id=0).plot(ax=ax,
            transform=ccrs.PlateCarree(), x='lon', y='lat',
            cmap='PuRd', # altere os valores de vmax para ver o que acontece
            add_colorbar=True)

states = NaturalEarthFeature(category='cultural', scale='50m', facecolor='none',
                             name='admin_1_states_provinces_lines')
contries = NaturalEarthFeature(category='cultural', scale='50m', facecolor='none',
                             name='admin_0_countries')

ax.add_feature(states, facecolor='none', edgecolor='black')
ax.add_feature(contries, facecolor='none', edgecolor='black')

parana.geometry.plot(ax=ax,facecolor='none',edgecolor='blue',linewidth=2)

ax.coastlines()

# %%
#Seleciona o período do CESM
precip_CESM = precip_CESM.sel(time=slice("1974", "2024"))
temp_CESM = temp_CESM.sel(time=slice("1974", "2024"))

# %%
precip_CESM['PRECT'] = precip_CESM['PRECC'] + precip_CESM['PRECL']

# %%
#Faz a série temporal para região
mean_prec = precip_CESM['PRECT'].mean(dim=["lat", "lon", "member_id"])
mean_temp = temp_CESM.mean(dim=["lat", "lon", "member_id"])

# %%
#Transforma as variáveis
mean_prec = mean_prec * 1000 * 24 * 60 * 60 * 30 #m/s --> mm/mês
mean_temp = mean_temp - 273.15 #Kelvin --> °C

# %%
mean_prec = mean_prec.sel(time=slice("1974", "2024"))
mean_temp = mean_temp.sel(time=slice("1974", "2024"))

# %%
# Salvando o DataFrame em um arquivo CSV
mean_prec.to_netcdf("./Dados/Media_precip_CESMLENS.nc")
mean_temp.to_netcdf("./Dados/Media_temp_CESMLENS.nc")
